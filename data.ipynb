# %%
import pandas as pd
df = pd.read_csv('employee_earnings.csv')
df
# Out:
#         the_geom  cartodb_id  the_geom_webmercator  calendar_year  quarter  \
# 0            NaN           1                   NaN           2020        3
# 1            NaN           2                   NaN           2022        1
# 2            NaN           3                   NaN           2019        3
# 3            NaN           4                   NaN           2020        4
# 4            NaN           5                   NaN           2019        2
# ...          ...         ...                   ...            ...      ...
# 616237       NaN      616238                   NaN           2023        2
# 616238       NaN      616239                   NaN           2023        2
# 616239       NaN      616240                   NaN           2023        2
# 616240       NaN      616241                   NaN           2023        2
# 616241       NaN      616242                   NaN           2023        2
#
#        last_name  first_name                                        title  \
# 0           Fant        Dana                             Police Officer 1
# 1           Fant        Dana                             Police Officer 1
# 2         Cousar    Reginald                           Custodial Worker 2
# 3          Jones       Wanda       Sanitation Collections Assistant Admin
# 4            Lee       David                              Police Sergeant
# ...          ...         ...                                          ...
# 616237   Harrell     Ezekiel              Building Maintenance Supervisor
# 616238    Gittel        Todd                             Police Officer 1
# 616239   Lepchuk  W. Matthew  Administrative Assistant - Non-Confidential
# 616240    Hitson    Kimberly                                Account Clerk
# 616241    Burgos   Breciendi                                    Detective
#
#        job_code             department_name  ...  base_gross_pay_qtd  \
# 0          6A02                  PPD Police  ...            20931.02
# 1          6A02                  PPD Police  ...            18446.40
# 2          7D12                  PPD Police  ...            10127.78
# 3          7A27                 STS Streets  ...            28463.37
# 4          6A04                  PPD Police  ...            19318.80
# ...         ...                         ...  ...                 ...
# 616237     7H61   FLP Free Library of Phila  ...             6349.58
# 616238     6A02                  PPD Police  ...             9546.00
# 616239     2L10    PPR Parks and Recreation  ...             4560.60
# 616240     1B10  DHS Dept of Human Services  ...             4774.63
# 616241     6A12                  PPD Police  ...            10500.30
#
#         longevity_gross_pay_qtd post_separation_gross_pay_qtd  \
# 0                       1711.33                           NaN
# 1                       1525.50                           NaN
# 2                        245.42                           NaN
# 3                        491.07                           NaN
# 4                       1400.98                           NaN
# ...                         ...                           ...
# 616237                   141.12                           NaN
# 616238                   966.84                           NaN
# 616239                    78.56                           NaN
# 616240                    94.83                           NaN
# 616241                   582.90                           NaN
#
#         miscellaneous_gross_pay_qtd  employee_category  compulsory_union_code  \
# 0                           7423.24      Civil Service                      P
# 1                           1514.94      Civil Service                      P
# 2                             90.45      Civil Service                      M
# 3                           -209.65      Civil Service                      N
# 4                           1258.76      Civil Service                      P
# ...                             ...                ...                    ...
# 616237                        45.09      Civil Service                      N
# 616238                      1052.45      Civil Service                      P
# 616239                         0.00      Civil Service                      J
# 616240                         0.00      Civil Service                      M
# 616241                       868.26      Civil Service                      P
#
#         termination_month  termination_year public_id  objectid
# 0                     NaN               NaN     24650  21627431
# 1                     NaN               NaN     24650  21627432
# 2                     NaN               NaN     21666  21627433
# 3                     NaN               NaN     17486  21627434
# 4                     NaN               NaN     11789  21627435
# ...                   ...               ...       ...       ...
# 616237                NaN               NaN     29693  22219296
# 616238                NaN               NaN     15289  22219297
# 616239                NaN               NaN      4704  22219298
# 616240                NaN               NaN     27943  22219299
# 616241                NaN               NaN     20915  22219300
#
# [616242 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['the_geom', 'cartodb_id', 'the_geom_webmercator', 'calendar_year',
#        'quarter', 'last_name', 'first_name', 'title', 'job_code',
#        'department_name', 'department_number', 'base_salary', 'salary_type',
#        'overtime_gross_pay_qtd', 'base_gross_pay_qtd',
#        'longevity_gross_pay_qtd', 'post_separation_gross_pay_qtd',
#        'miscellaneous_gross_pay_qtd', 'employee_category',
#        'compulsory_union_code', 'termination_month', 'termination_year',
#        'public_id', 'objectid'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# the_geom                         616242
# cartodb_id                            0
# the_geom_webmercator             616242
# calendar_year                         0
# quarter                               0
# last_name                             0
# first_name                            0
# title                                 0
# job_code                              0
# department_name                       0
# department_number                     0
# base_salary                       29186
# salary_type                           4
# overtime_gross_pay_qtd           301837
# base_gross_pay_qtd                    0
# longevity_gross_pay_qtd          208757
# post_separation_gross_pay_qtd    607304
# miscellaneous_gross_pay_qtd           0
# employee_category                     0
# compulsory_union_code                32
# termination_month                576426
# termination_year                 576426
# public_id                             0
# objectid                              0
# dtype: int64

# %%
columns_to_drop = ['the_geom', 'cartodb_id', 'job_code', 'the_geom_webmercator', 'post_separation_gross_pay_qtd']
df = df.drop(columns_to_drop, axis=1)
df
# Out:
#         calendar_year  quarter last_name  first_name  \
# 0                2020        3      Fant        Dana
# 1                2022        1      Fant        Dana
# 2                2019        3    Cousar    Reginald
# 3                2020        4     Jones       Wanda
# 4                2019        2       Lee       David
# ...               ...      ...       ...         ...
# 616237           2023        2   Harrell     Ezekiel
# 616238           2023        2    Gittel        Todd
# 616239           2023        2   Lepchuk  W. Matthew
# 616240           2023        2    Hitson    Kimberly
# 616241           2023        2    Burgos   Breciendi
#
#                                               title  \
# 0                                  Police Officer 1
# 1                                  Police Officer 1
# 2                                Custodial Worker 2
# 3            Sanitation Collections Assistant Admin
# 4                                   Police Sergeant
# ...                                             ...
# 616237              Building Maintenance Supervisor
# 616238                             Police Officer 1
# 616239  Administrative Assistant - Non-Confidential
# 616240                                Account Clerk
# 616241                                    Detective
#
#                    department_name  department_number  base_salary  \
# 0                       PPD Police                 11      78092.0
# 1                       PPD Police                 11      80240.0
# 2                       PPD Police                 11      38023.0
# 3                      STS Streets                 12      96433.0
# 4                       PPD Police                 11      83714.0
# ...                            ...                ...          ...
# 616237   FLP Free Library of Phila                 52      71283.0
# 616238                  PPD Police                 11      83048.0
# 616239    PPR Parks and Recreation                 16      53822.0
# 616240  DHS Dept of Human Services                 22      41577.0
# 616241                  PPD Police                 11      91352.0
#
#        salary_type  overtime_gross_pay_qtd  base_gross_pay_qtd  \
# 0         Salaried                 3500.96            20931.02
# 1         Salaried                 6801.97            18446.40
# 2         Salaried                 1151.38            10127.78
# 3         Salaried                  985.28            28463.37
# 4         Salaried                 1660.21            19318.80
# ...            ...                     ...                 ...
# 616237    Salaried                 3899.67             6349.58
# 616238    Salaried                 7994.58             9546.00
# 616239    Salaried                     NaN             4560.60
# 616240    Salaried                     NaN             4774.63
# 616241    Salaried                 3970.42            10500.30
#
#         longevity_gross_pay_qtd  miscellaneous_gross_pay_qtd  \
# 0                       1711.33                      7423.24
# 1                       1525.50                      1514.94
# 2                        245.42                        90.45
# 3                        491.07                      -209.65
# 4                       1400.98                      1258.76
# ...                         ...                          ...
# 616237                   141.12                        45.09
# 616238                   966.84                      1052.45
# 616239                    78.56                         0.00
# 616240                    94.83                         0.00
# 616241                   582.90                       868.26
#
#        employee_category compulsory_union_code  termination_month  \
# 0          Civil Service                     P                NaN
# 1          Civil Service                     P                NaN
# 2          Civil Service                     M                NaN
# 3          Civil Service                     N                NaN
# 4          Civil Service                     P                NaN
# ...                  ...                   ...                ...
# 616237     Civil Service                     N                NaN
# 616238     Civil Service                     P                NaN
# 616239     Civil Service                     J                NaN
# 616240     Civil Service                     M                NaN
# 616241     Civil Service                     P                NaN
#
#         termination_year  public_id  objectid
# 0                    NaN      24650  21627431
# 1                    NaN      24650  21627432
# 2                    NaN      21666  21627433
# 3                    NaN      17486  21627434
# 4                    NaN      11789  21627435
# ...                  ...        ...       ...
# 616237               NaN      29693  22219296
# 616238               NaN      15289  22219297
# 616239               NaN       4704  22219298
# 616240               NaN      27943  22219299
# 616241               NaN      20915  22219300
#
# [616242 rows x 19 columns]
